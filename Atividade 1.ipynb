# %%
import pandas as pd
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
from scipy import stats
from matplotlib.ticker import StrMethodFormatter

# %%
data = pd.read_excel('./desempenholoja.xlsx')

# %%
data.describe()
# Out:
#              loja  Porte da loja     compet1     compet2     compet3  \
# count  256.000000     256.000000  256.000000  256.000000  256.000000
# mean   128.500000       3.390625    3.793008    3.592969    3.770469
# std     74.045031       1.384703    0.547740    0.660243    0.554362
# min      1.000000       1.000000    1.930000    0.000000    2.430000
# 25%     64.750000       2.000000    3.487500    3.250000    3.387500
# 50%    128.500000       4.000000    3.840000    3.620000    3.835000
# 75%    192.250000       5.000000    4.190000    4.000000    4.202500
# max    256.000000       5.000000    5.000000    4.950000    4.960000
#
#           compet4     compet5     compet6  competmedia  desempenhofinal  ...  \
# count  256.000000  256.000000  256.000000   256.000000       256.000000  ...
# mean     3.886406    3.604844    3.756094     3.739062        88.905898  ...
# std      0.497947    0.570372    0.679266     0.511037         7.954804  ...
# ...

# %%
data.describe()
def showHist(data, column, x_label, y_label):
    ax = data.hist(column=column, bins=25, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

    ax = ax[0]
    for x in ax:

        # Despine
        x.spines['right'].set_visible(False)
        x.spines['top'].set_visible(False)
        x.spines['left'].set_visible(False)

        # Switch off ticks
        x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

        # Draw horizontal axis lines
        vals = x.get_yticks()
        for tick in vals:
            x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

        # Remove title
        x.set_title("Histograma")

        # Set x-axis label
        x.set_xlabel(x_label, labelpad=20, weight='bold', size=12)

        # Set y-axis label
        x.set_ylabel(y_label, labelpad=20, weight='bold', size=12)

        # Format y-axis label
        x.yaxis.set_major_formatter(StrMethodFormatter('{x:g}'))

# %%
showHist(data,'Porte da loja',  'Porte da loja', 'Quantidade de lojas')

# %%
x = data.boxplot(column=['compet1', 'compet2', 'compet3' ,'compet4','compet5','compet6'], showmeans=True, grid=False, figsize=(12,8))


# Despine
x.spines['right'].set_visible(False)
x.spines['top'].set_visible(False)
x.spines['left'].set_visible(False)

# Switch off ticks
x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw horizontal axis lines
vals = x.get_yticks()
for tick in vals:
    x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Remove title

# Set x-axis label
x.set_xlabel("Competencias", labelpad=20, weight='bold', size=12)

# Set y-axis label
x.set_ylabel("Avaliacao", labelpad=20, weight='bold', size=12)

# Format y-axis label
x.yaxis.set_major_formatter(StrMethodFormatter('{x:g}'))

# %%
column1=[u'desemp1', u'desemp2', u'desemp3', u'desemp4', u'desemp5', u'desemp6', u'desemp7', u'desemp8', u'desemp9', u'desemp10']
column2=[u'desemp11', u'desemp12', u'desemp13', u'desemp14', u'desemp15', u'desemp16', u'desemp17', u'desemp18', u'desemp19', u'desemp20'] 
column3=[u'desemp21', u'desemp22', u'desemp23', u'desemp24', u'desemp25', u'desemp26', u'desemp27', u'desemp28', u'desemp29', u'desemp30'] 
column4=[u'desemp31', u'desemp32', u'desemp33', u'desemp34', u'desemp35', u'desemp36', u'desemp37', u'desemp38', u'desemp39', u'desemp40'] 
column5=[u'desemp41', u'desemp42', u'desemp43', u'desemp44', u'desemp45', u'desemp46', u'desemp47', u'desemp48', u'desemp49', u'desemp50'] 
column6=[u'desemp51', u'desemp52', u'desemp53', u'desemp54', u'desemp55', u'desemp56', u'desemp57', u'desemp58', u'desemp59', u'desemp60'] 
column7=[u'desemp61', u'desemp62', u'desemp63', u'desemp64', u'desemp65', u'desemp66', u'desemp67', u'desemp68', u'desemp69']

columnsA = ['desemp4', 'desemp11','desemp12','desemp13','desemp14','desemp30','desemp38','desemp50', 'desemp57' ]

dataco = data[columnsA]
datawio = dataco[(np.abs(stats.zscore(dataco)) < 3).all(axis=1)]

x = dataco.boxplot(columnsA, showmeans=True, grid=False, figsize=(12,8))


# Despine
x.spines['right'].set_visible(False)
x.spines['top'].set_visible(False)
x.spines['left'].set_visible(False)

# Switch off ticks
x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw horizontal axis lines
vals = x.get_yticks()
for tick in vals:
    x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Remove title

# Set x-axis label
x.set_xlabel("Competencias", labelpad=20, weight='bold', size=12)

# Set y-axis label
x.set_ylabel("Avaliacao", labelpad=20, weight='bold', size=12)

# Format y-axis label
x.yaxis.set_major_formatter(StrMethodFormatter('{x:g}'))

# %%
db1 = data[data['Porte da loja'] ==1]
db2 = data[data['Porte da loja'] ==2]
db3 = data[data['Porte da loja'] ==3]
db4 = data[data['Porte da loja'] ==4]
db5 = data[data['Porte da loja'] ==5]



db1.boxplot(column=['compet1', 'compet2', 'compet3' ,'compet4','compet5','compet6', 'competmedia'],grid=False, figsize=(12,8))

# %%
db2.boxplot(column=['compet1', 'compet2', 'compet3' ,'compet4','compet5','compet6'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-26403a1cdd95> in <module>()
# ----> 1 db2.boxplot(column=['compet1', 'compet2', 'compet3' ,'compet4','compet5','compet6'])
#
# NameError: name 'db2' is not defined

# %%
db3.boxplot(column=['compet1', 'compet2', 'compet3' ,'compet4','compet5','compet6', 'competmedia'])

# %%
db4.boxplot(column=['compet1', 'compet2', 'compet3' ,'compet4','compet5','compet6', 'competmedia'], showmeans=True)

# %%
x = data.boxplot(column=['competmedia'], by=['Porte da loja'], showmeans=True, grid=False, figsize=(12,8))


# Despine
x.spines['right'].set_visible(False)
x.spines['top'].set_visible(False)
x.spines['left'].set_visible(False)

# Switch off ticks
x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw horizontal axis lines
vals = x.get_yticks()
for tick in vals:
    x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Remove title
x.set_title('')

# Set x-axis label
x.set_ylabel("Competencia media", labelpad=20, weight='bold', size=12)

# Set y-axis label
x.set_xlabel("Porte da loja", labelpad=20, weight='bold', size=12)

# Format y-axis label
x.yaxis.set_major_formatter(StrMethodFormatter('{x:g}'))

# %%
data.boxplot(column=['desempenhofinal'], by=['Porte da loja'],  showmeans=True)

# %%
data.boxplot(column=['desempenhofinal'], by=['competmedia'])

# %%
data['competint'] = data['competmedia'].astype(int)
data['competint']
data.boxplot(column=['desempenhofinal'], by=['competint'], showmeans=True)

# %%
data.desemp65.sats
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-67bb694b8afd> in <module>()
# ----> 1 data.desemp65.sats
#
# /Users/abraao/anaconda3/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'sats'

# %%
data.desemp65.std()
# Out:
# 7787.232583004196
